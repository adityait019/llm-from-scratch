# %%
import pandas as pd

df=pd.read_json(r'C:\tcs\archive\GOT\season1.json')
df.head(2)
# Out:
#    Game Of Thrones S01E01 Winter Is Coming.srt  \
# 1                                   Easy, boy.
# 10     Our orders were to track the wildlings.
#
#    Game Of Thrones S01E02 The Kingsroad.srt  \
# 1                 You need to drink, child.
# 10        The Dothraki believe that one day
#
#    Game Of Thrones S01E03 Lord Snow.srt  \
# 1                  Welcome, Lord Stark.
# 10                    Sturdy old thing.
#
#    Game Of Thrones S01E04 Cripples, Bastards, And Broken Things.srt  \
# 1              The little lord's been dreaming again.
# 10                - Hodor? - Help Bran down the hall.
#
#    Game Of Thrones S01E05 The Wolf And The Lion.srt  \
# 1     Does Ser Hugh have any family in the capital?
# 10                        But who holds the straws?
#
#    Game Of Thrones S01E06 A Golden Crown.srt  \
# 1                   Your pardon, Your Grace.
# 10                      He butchered my men.
#
#    Game Of Thrones S01E07 You Win Or You Die.srt  \
# ...

# %%
df.shape
# Out:
# (775, 10)

# %%
df.columns
# Out:
# Index(['Game Of Thrones S01E01 Winter Is Coming.srt',
#        'Game Of Thrones S01E02 The Kingsroad.srt',
#        'Game Of Thrones S01E03 Lord Snow.srt',
#        'Game Of Thrones S01E04 Cripples, Bastards, And Broken Things.srt',
#        'Game Of Thrones S01E05 The Wolf And The Lion.srt',
#        'Game Of Thrones S01E06 A Golden Crown.srt',
#        'Game Of Thrones S01E07 You Win Or You Die.srt',
#        'Game Of Thrones S01E08 The Pointy End.srt',
#        'Game Of Thrones S01E09 Baelor.srt',
#        'Game Of Thrones S01E10 Fire And Blood.srt'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 775 entries, 1 to 775
# Data columns (total 10 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Game Of Thrones S01E01 Winter Is Coming.srt                       559 non-null    object
#  1   Game Of Thrones S01E02 The Kingsroad.srt                          571 non-null    object
#  2   Game Of Thrones S01E03 Lord Snow.srt                              740 non-null    object
#  3   Game Of Thrones S01E04 Cripples, Bastards, And Broken Things.srt  754 non-null    object
#  4   Game Of Thrones S01E05 The Wolf And The Lion.srt                  741 non-null    object
#  5   Game Of Thrones S01E06 A Golden Crown.srt                         583 non-null    object
#  6   Game Of Thrones S01E07 You Win Or You Die.srt                     775 non-null    object
# ...

# %%
df=df.fillna('')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 775 entries, 1 to 775
# Data columns (total 10 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Game Of Thrones S01E01 Winter Is Coming.srt                       775 non-null    object
#  1   Game Of Thrones S01E02 The Kingsroad.srt                          775 non-null    object
#  2   Game Of Thrones S01E03 Lord Snow.srt                              775 non-null    object
#  3   Game Of Thrones S01E04 Cripples, Bastards, And Broken Things.srt  775 non-null    object
#  4   Game Of Thrones S01E05 The Wolf And The Lion.srt                  775 non-null    object
#  5   Game Of Thrones S01E06 A Golden Crown.srt                         775 non-null    object
#  6   Game Of Thrones S01E07 You Win Or You Die.srt                     775 non-null    object
# ...

# %%
df.head(10)
# Out:
#            Game Of Thrones S01E01 Winter Is Coming.srt  \
# 1                                           Easy, boy.
# 10             Our orders were to track the wildlings.
# 100                       - Right. Give it here. - No!
# 101                               Put away your blade.
# 102  - I take orders from your father, not you. - P...
# 103                                   I'm sorry, Bran.
# 104                                        Lord Stark?
# 105                               There are five pups.
# 106                One for each of the Stark children.
# 107           The direwolf is the sigil of your house.
#
#               Game Of Thrones S01E02 The Kingsroad.srt  \
# 1                            You need to drink, child.
# 10                   The Dothraki believe that one day
# 100                               Such a little thing.
# 101                           A bird without feathers.
# 102                    They came to take his body away
# ...
